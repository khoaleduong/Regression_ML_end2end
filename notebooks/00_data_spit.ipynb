# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/leduongkhoa/Regression_MachineLearning_End2End/data/raw/untouched_raw_original.csv")

# %%
pd.set_option('display.max_columns', None) # show all cols
pd.set_option('display.max_rows', 100)    # show max 100 rows
# pd.options.display.max_rows = 100

# %%
df.shape
# Out:
# (884092, 39)

# %%
df.head(5)
# Out:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2012-03-31            46550.0           217450.0    31.813674
# 1  2012-04-30            61870.0           245000.0    40.723982
# 2  2012-05-31           125500.0           217450.0    63.913043
# 3  2012-06-30           153000.0           189900.0    81.598080
# 4  2012-07-31           165500.0           154000.0    81.598080
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        110.183666        14.0           23.0          44.0       64.0
# 1        130.528256        22.0           29.0          56.0       69.0
# 2        119.919216        24.0           40.0          63.0       60.0
# 3        105.617353        34.0           46.0          50.0       57.0
# 4         83.921175        39.0           49.0          42.0       50.0
#
#    median_dom  avg_sale_to_list  sold_above_list  off_market_in_two_weeks  \
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
print(df['date'].dt.year.value_counts().sort_index())
# Out:
# 2012    62260
# 2013    74712
# 2014    74712
# 2015    74712
# 2016    74712
# 2017    74712
# 2018    74712
# 2019    74712
# 2020    74712
# 2021    74712
# 2022    74712
# 2023    74712
# Name: date, dtype: int64

# %%
df = df.sort_values(by=['date']).reset_index(drop=True)

# %% [markdown]
# ### Avoid Leakage
#
# * **Train set (2012–2019):** This is "clean" historical training data.
# * **Eval set (2020–2021):** This data is "unseen" during the actual training process, but it is still used for validation and hyperparameter tuning.
# * **Holdout set (2022–2023):** This set remains completely untouched until the very end of the project to ensure an unbiased final evaluation.

# %%
evel_cut_off_date = pd.to_datetime("2020-01-01") # YYYY-MM-DD format
holdout_cut_off_date = pd.to_datetime("2022-01-01") # YYYY-MM-DD format

# %%
train_df = df[df['date'] < evel_cut_off_date]
eval_df = df[(df['date'] >= evel_cut_off_date) & (df['date'] < holdout_cut_off_date)]
holdout_df = df[df['date'] >= holdout_cut_off_date]

print(f"Train_df shape: {train_df.shape}")
print(f"Eval_df shape: {eval_df.shape}")
print(f"Holdout_df shape: {holdout_df.shape}")
# Out:
# Train_df shape: (585244, 39)
# Eval_df shape: (149424, 39)
# Holdout_df shape: (149424, 39)

# %%
train_df.head(3)
# Out:
#         date  median_sale_price  median_list_price  median_ppsf  \
# 0 2012-03-31            46550.0           217450.0    31.813674
# 1 2012-03-31           200000.0             7500.0   104.931794
# 2 2012-03-31            75750.0            92400.0   165.898618
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        110.183666        14.0           23.0          44.0       64.0
# 1         79.265873         1.0            1.0           1.0        2.0
# 2         63.412698         2.0            2.0           4.0       13.0
#
#    median_dom  avg_sale_to_list  sold_above_list  off_market_in_two_weeks  \
# 0        59.5          0.943662         0.142857                 0.043478
# 1       290.0          0.909091         0.000000                 0.000000
# 2       193.0          0.986815         0.000000                 0.000000
#
#   city  zipcode  year  bank  bus  hospital  mall  park  restaurant  school  \
# ...

# %%
eval_df.head(3)
# Out:
#              date  median_sale_price  median_list_price  median_ppsf  \
# 585244 2020-01-31           184000.0           168450.0   123.333333
# 585245 2020-01-31           140000.0           139000.0    94.691957
# 585246 2020-01-31          1040000.0          1600000.0  1386.111111
#
#         median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 585244        109.899800        35.0           30.0          34.0       37.0
# 585245        111.311054        61.0           81.0          83.0       54.0
# 585246       1801.309410       134.0          151.0         210.0      563.0
#
#         median_dom  avg_sale_to_list  sold_above_list  \
# 585244        50.0          0.954732         0.171429
# 585245        10.0          0.963039         0.098361
# 585246       188.0          0.971567         0.037313
#
#         off_market_in_two_weeks city  zipcode  year   bank   bus  hospital  \
# 585244                 0.300000  CHI    60482  2020    3.0   0.0       2.0
# ...

# %%
holdout_df.head(3)
# Out:
#              date  median_sale_price  median_list_price  median_ppsf  \
# 734668 2022-01-31           340000.0           349999.0   189.867865
# 734669 2022-01-31           310000.0           269900.0   243.839836
# 734670 2022-01-31           274950.0           299450.0   175.320145
#
#         median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 734668        195.526649       282.0          287.0         241.0       73.0
# 734669        239.543726        49.0           47.0          43.0        7.0
# 734670        287.500000         4.0            3.0           6.0        2.0
#
#         median_dom  avg_sale_to_list  sold_above_list  \
# 734668        12.0          0.991177         0.308511
# 734669         6.5          1.006586         0.489796
# 734670        33.0          0.975694         0.000000
#
#         off_market_in_two_weeks city  zipcode  year  bank  bus  hospital  \
# 734668                 0.634146  ORL    32771  2022   9.0  0.0       1.0
# ...

# %%
train_df.to_csv("/Users/leduongkhoa/Regression_MachineLearning_End2End/data/raw/train.csv", index=False)
eval_df.to_csv("/Users/leduongkhoa/Regression_MachineLearning_End2End/data/raw/eval.csv", index=False)
holdout_df.to_csv("/Users/leduongkhoa/Regression_MachineLearning_End2End/data/raw/holdout.csv", index=False)
